# %%
import pandas as pd

publi = pd.read_csv('https://raw.githubusercontent.com/XMUR/ISLR-1/master/Advertising.csv',index_col=0)
publi.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
print(publi.shape)
# Out:
# (200, 4)

# %%
x = publi[['TV','Radio','Newspaper']]
y = publi['Sales']

# %%
x.shape
# Out:
# (200, 3)

# %%
y.shape
# Out:
# (200,)

# %%
import seaborn as sns
sns.pairplot(publi, x_vars=['TV','Radio','Newspaper'], y_vars='Sales',kind='reg')

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3)

# %% [markdown]
# ### Importação do modelo de regressão linear

# %%
from sklearn.linear_model import LinearRegression
reglin = LinearRegression()
reglin.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Coeficientes:Aumento nas vendas para cada 1un investida em publicidade

# %%
list(zip(['TV','Radio','Newspaper'],reglin.coef_))
# Out:
# [('TV', 0.04724211678219766),
#  ('Radio', 0.18540829468453413),
#  ('Newspaper', 0.0016078774152806508)]

# %% [markdown]
# ### Previsao

# %%
y_prev = reglin.predict(x_test)
print(y_prev)
# Out:
# [ 9.57838589 11.93565449 17.15713131  8.70271505 21.38670639  7.63545728
#  11.66741562 17.24912005 10.00697829 15.22340217  8.78056821  6.4095952
#  16.33233443 12.67091332 20.81014899 11.94255919 14.92847006 18.32292881
#  17.86250454  9.91807718  7.56828951 17.20901663 17.12597815  7.0136196
#  20.01691922  6.45361723 15.75024214 16.82539118 12.14567721 20.64011672
#   8.99898148 16.84246865 18.90616147 14.49501959 20.27110547 12.24806983
#  21.03446436 10.92096755 21.65899643  8.27141365 15.50890394 18.54753594
#   5.16285526 13.80959356 12.77191542 10.54352943 14.18927733 10.06560148
#  12.74644922 13.80810516 21.07525632  9.69298019 15.23250039  8.02173885
#  24.32484205 23.29552521  9.290261   14.90057625  9.74945568  7.75983621]

# %%
print(y_test)
# Out:
# 150    10.1
# 68     13.4
# 36     12.8
# 67      9.5
# 94     22.2
# 66      9.3
# 89     12.9
# 12     17.4
# 158    10.1
# 200    13.4
# 47     10.6
# 183     8.7
# 195    17.3
# 58     13.2
# 16     22.4
# 174    11.7
# 111    13.4
# 194    19.6
# 106    19.2
# 91     11.2
# 33      9.6
# 164    18.0
# 28     15.9
# 108     8.7
# 177    20.2
# 128     8.8
# 26     12.0
# 65     18.0
# 191    10.8
# 1      22.1
# 126    10.6
# 100    17.2
# 34     17.4
# 166    11.9
# 105    20.7
# 6       7.2
# 138    20.8
# 165    11.9
# 43     20.7
# 57      5.5
# 88     16.0
# 151    16.1
# 196     7.6
# 113    14.1
# 116    12.6
# 181    10.5
# 84     13.6
# 73      8.8
# 198    12.8
# 175    11.5
# 70     22.3
# 39     10.1
# 157    15.3
# 197     9.7
# 184    26.2
# 148    25.4
# 141    10.9
# 124    15.2
# 19     11.3
# 130     9.7
# Name: Sales, dtype: float64

# %% [markdown]
# ### Avaliação da Performance
#
# ### MAE(Mean absolute error)

# %%
from sklearn import metrics

# %%
print(metrics.mean_absolute_error(y_test,y_prev))
# Out:
# 1.3518796531270365

# %% [markdown]
# ### MSE(Mean squared error)

# %%
print(metrics.mean_squared_error(y_test,y_prev))
# Out:
# 2.8658375651985164

# %% [markdown]
# ### RMSE(Root mean squared error)

# %%
import numpy as np
print(np.sqrt(metrics.mean_squared_error(y_test,y_prev)))
# Out:
# 1.6928784850657523
